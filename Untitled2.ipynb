# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[104], line 4
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 import sklearn.preproi
#
# ModuleNotFoundError: No module named 'sklearn.preproi'

# %%
dataset = pd.read_excel("zeeshan2222prac.xlsx")
dataset.head(3)
# Out:
#   JE Code      Store Country Region                 Date             Item  \
# 0  I-1001     Moscow  Russia   EMEA  2018-10-06 00:00:00        Microwave
# 1  I-1002    Toronto  Canada    NaN            4/23/2015        Microwave
# 2  I-1003  Sao Paolo  Brazil  LATAM  2017-04-03 00:00:00  Air conditioner
#
#      Salesperson  List Price  Actual Price  Discount
# 0     May Wilmot          80            79     0.0125
# 1   David Shiner          80            54     0.3250
# 2  Gary Reynolds         700           686     0.0200

# %%
dataset.drop('Date' , inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 dataset.drop('Date' , inplace=True)
#
# File E:\anaconda\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File E:\anaconda\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File E:\anaconda\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File E:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Date'] not found in axis"

# %%
dataset.isnull().sum()
# Out:
# JE Code         0
# Store           0
# Country         0
# Date            0
# Item            0
# Salesperson     0
# List Price      0
# Actual Price    0
# Discount        0
# dtype: int64

# %%
dataset.drop('Region',axis=1,inplace=True)

# %%
dataset
# Out:
#      JE Code      Store    Country                 Date             Item  \
# 0     I-1001     Moscow     Russia  2018-10-06 00:00:00        Microwave
# 1     I-1002    Toronto     Canada            4/23/2015        Microwave
# 2     I-1003  Sao Paolo     Brazil  2017-04-03 00:00:00  Air conditioner
# 3     I-1004   Istanbul     Turkey            8/14/2018      Ceiling fan
# 4     I-1005     Sydney  Australia  2015-03-03 00:00:00          Toaster
# ...      ...        ...        ...                  ...              ...
# 2334  I-3335     Vienna    Austria           12/19/2017        Microwave
# 2335  I-3336   Shenzhen      China            2/17/2015        Microwave
# 2336  I-3337   Istanbul     Turkey            5/27/2015  Washing Machine
# 2337  I-3338     Athens     Greece  2016-07-10 00:00:00   Coffee grinder
# 2338  I-3339   Shanghai      China  2017-02-09 00:00:00        Microwave
#
#             Salesperson  List Price  Actual Price  Discount
# 0            May Wilmot          80            79     0.0125
# 1          David Shiner          80            54     0.3250
# 2         Gary Reynolds         700           686     0.0200
# 3          Mark Buntain         150           137     0.0867
# 4      Christine Davies          50            37     0.2600
# ...                 ...         ...           ...        ...
# 2334    Raymond Denning          80            78     0.0250
# 2335  Phillip Humphreys          80            78     0.0250
# 2336        David Philp         800           480     0.4000
# 2337    Richard Perrott          70            64     0.0857
# 2338     Glenys Raymond          80            77     0.0375
#
# [2339 rows x 9 columns]

# %%
dataset.describe()
# Out:
#         List Price  Actual Price    Discount
# count  2339.000000   2339.000000  2339.000000
# mean    340.162463    289.874305     0.116508
# std     325.668713    269.497560     0.120096
# min      30.000000      8.000000     0.000000
# 25%      50.000000     49.000000     0.025000
# 50%     150.000000    147.000000     0.080000
# 75%     500.000000    500.000000     0.166700
# max    1000.000000   1000.000000     0.800000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2339 entries, 0 to 2338
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   JE Code       2339 non-null   object
#  1   Store         2339 non-null   object
#  2   Country       2339 non-null   object
#  3   Date          2339 non-null   object
#  4   Item          2339 non-null   object
#  5   Salesperson   2339 non-null   object
#  6   List Price    2339 non-null   int64
#  7   Actual Price  2339 non-null   int64
#  8   Discount      2339 non-null   float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 164.6+ KB

# %%
dataset.select_dtypes(include="object")
# Out:
#      JE Code      Store    Country                 Date             Item  \
# 0     I-1001     Moscow     Russia  2018-10-06 00:00:00        Microwave
# 1     I-1002    Toronto     Canada            4/23/2015        Microwave
# 2     I-1003  Sao Paolo     Brazil  2017-04-03 00:00:00  Air conditioner
# 3     I-1004   Istanbul     Turkey            8/14/2018      Ceiling fan
# 4     I-1005     Sydney  Australia  2015-03-03 00:00:00          Toaster
# ...      ...        ...        ...                  ...              ...
# 2334  I-3335     Vienna    Austria           12/19/2017        Microwave
# 2335  I-3336   Shenzhen      China            2/17/2015        Microwave
# 2336  I-3337   Istanbul     Turkey            5/27/2015  Washing Machine
# 2337  I-3338     Athens     Greece  2016-07-10 00:00:00   Coffee grinder
# 2338  I-3339   Shanghai      China  2017-02-09 00:00:00        Microwave
#
#             Salesperson
# 0            May Wilmot
# 1          David Shiner
# 2         Gary Reynolds
# 3          Mark Buntain
# 4      Christine Davies
# ...                 ...
# 2334    Raymond Denning
# 2335  Phillip Humphreys
# 2336        David Philp
# 2337    Richard Perrott
# 2338     Glenys Raymond
#
# [2339 rows x 6 columns]

# %%
dataset.select_dtypes(include="object").columns
# Out:
# Index(['JE Code', 'Store', 'Country', 'Date', 'Item', 'Salesperson'], dtype='object')

# %%
dataset
# Out:
#      JE Code      Store    Country                 Date             Item  \
# 0     I-1001     Moscow     Russia  2018-10-06 00:00:00        Microwave
# 1     I-1002    Toronto     Canada            4/23/2015        Microwave
# 2     I-1003  Sao Paolo     Brazil  2017-04-03 00:00:00  Air conditioner
# 3     I-1004   Istanbul     Turkey            8/14/2018      Ceiling fan
# 4     I-1005     Sydney  Australia  2015-03-03 00:00:00          Toaster
# ...      ...        ...        ...                  ...              ...
# 2334  I-3335     Vienna    Austria           12/19/2017        Microwave
# 2335  I-3336   Shenzhen      China            2/17/2015        Microwave
# 2336  I-3337   Istanbul     Turkey            5/27/2015  Washing Machine
# 2337  I-3338     Athens     Greece  2016-07-10 00:00:00   Coffee grinder
# 2338  I-3339   Shanghai      China  2017-02-09 00:00:00        Microwave
#
#             Salesperson  List Price  Actual Price  Discount
# 0            May Wilmot          80            79     0.0125
# 1          David Shiner          80            54     0.3250
# 2         Gary Reynolds         700           686     0.0200
# 3          Mark Buntain         150           137     0.0867
# 4      Christine Davies          50            37     0.2600
# ...                 ...         ...           ...        ...
# 2334    Raymond Denning          80            78     0.0250
# 2335  Phillip Humphreys          80            78     0.0250
# 2336        David Philp         800           480     0.4000
# 2337    Richard Perrott          70            64     0.0857
# 2338     Glenys Raymond          80            77     0.0375
#
# [2339 rows x 9 columns]

# %%
from sklearn.impute import SimpleImputer

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 2
#       1 si = SimpleImputer(strategy="mean")
# ----> 2 si.fit_transform([ 'Store', 'Country', 'Date', 'Item', 'Salesperson'])
#
# File E:\anaconda\Lib\site-packages\sklearn\utils\_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File E:\anaconda\Lib\site-packages\sklearn\base.py:1098, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1083         warnings.warn(
#    1084             (
#    1085                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#    1093             UserWarning,
#    1094         )
#    1096 if y is None:
#    1097     # fit method of arity 1 (unsupervised transformation)
# -> 1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
#    1101     return self.fit(X, y, **fit_params).transform(X)
#
# File E:\anaconda\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File E:\anaconda\Lib\site-packages\sklearn\impute\_base.py:410, in SimpleImputer.fit(self, X, y)
#     392 @_fit_context(prefer_skip_nested_validation=True)
#     393 def fit(self, X, y=None):
#     394     """Fit the imputer on `X`.
#     395
#     396     Parameters
#    (...)
#     408         Fitted estimator.
#     409     """
# --> 410     X = self._validate_input(X, in_fit=True)
#     412     # default fill_value is 0 for numerical input and "missing_value"
#     413     # otherwise
#     414     if self.fill_value is None:
#
# File E:\anaconda\Lib\site-packages\sklearn\impute\_base.py:337, in SimpleImputer._validate_input(self, X, in_fit)
#     331 if "could not convert" in str(ve):
#     332     new_ve = ValueError(
#     333         "Cannot use {} strategy with non-numeric data:\n{}".format(
#     334             self.strategy, ve
#     335         )
#     336     )
# --> 337     raise new_ve from None
#     338 else:
#     339     raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: 'Store'
